# %% [markdown]
# # Quickstart Notebook
#
# This notebook loads a CSV dataset using the shared dataloader utilities.

# %%
from pathlib import Path
import sys

# Ensure project root is on sys.path for imports
project_root = Path("../..").resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from dataloader import load_txt, preprocess, GWASDataset

data_path = Path("../../data/tmpDATA-Leon/donnees_MRI_MDD_fixed_only_variants_clumping_p_thr_0.001all.txt")

df = load_txt(data_path)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4045 entries, 0 to 4044
# Columns: 1012 entries, Mean_intensity_3rd-Ventricle_whole-brain to ID
# dtypes: float64(1011), str(1)
# memory usage: 31.2 MB

# %%
X_train, y_train, X_test, y_test = preprocess(df=df, target="Z_scores_MDD", testsize = 0.2)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(GWASDataset(X_train, y_train), batch_size=32, shuffle=True)
test_loader = DataLoader(GWASDataset(X_test, y_test), batch_size=32, shuffle=False)

# %%
from model import DNN

model = DNN(input_dim=X_train.shape[1], hidden_dims=[500, 100, 10], output_dim=1)
print(model)
# Out:
# DNN(
#   (network): Sequential(
#     (0): Linear(in_features=1010, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=500, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
from torch import nn, optim
import torch

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

train_losses = []
test_losses = []
 
for epoch in range(100):
    model.train()
    total_loss = 0
    for batch_X, batch_y in train_loader:
        optimizer.zero_grad()
        predictions = model(batch_X)
        loss = criterion(predictions, batch_y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * batch_X.size(0)
    train_losses.append(total_loss / len(train_loader.dataset))
    print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

    model.eval()
    test_loss = 0
    criterion = nn.MSELoss()
 
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            predictions = model(batch_X)
            loss = criterion(predictions, batch_y)
            test_loss += loss.item() * batch_X.size(0)
    
    average_test_loss = test_loss / len(test_loader.dataset)
    test_losses.append(average_test_loss)
    print(f"Test Mean Squared Error: {average_test_loss:.4f}")
# Out:
# Epoch 1, Loss: 1352.8228
# Test Mean Squared Error: 13.2053
# Epoch 2, Loss: 1347.7161
# Test Mean Squared Error: 13.2049
# Epoch 3, Loss: 1345.4991
# Test Mean Squared Error: 13.2039
# Epoch 4, Loss: 1346.1759
# Test Mean Squared Error: 13.2061
# Epoch 5, Loss: 1347.0587
# Test Mean Squared Error: 13.2057
# Epoch 6, Loss: 1347.8265
# Test Mean Squared Error: 13.2031
# Epoch 7, Loss: 1347.6874
# Test Mean Squared Error: 13.2031
# Epoch 8, Loss: 1348.2303
# Test Mean Squared Error: 13.2050
# Epoch 9, Loss: 1347.4307
# Test Mean Squared Error: 13.2038
# Epoch 10, Loss: 1348.3908
# Test Mean Squared Error: 13.2033
# Epoch 11, Loss: 1348.3392
# Test Mean Squared Error: 13.2052
# Epoch 12, Loss: 1346.9318
# Test Mean Squared Error: 13.2033
# Epoch 13, Loss: 1346.2648
# Test Mean Squared Error: 13.2032
# Epoch 14, Loss: 1346.7693
# Test Mean Squared Error: 13.2034
# Epoch 15, Loss: 1345.6052
# Test Mean Squared Error: 13.2035
# Epoch 16, Loss: 1347.1362
# Test Mean Squared Error: 13.2032
# Epoch 17, Loss: 1346.5873
# Test Mean Squared Error: 13.2038
# Epoch 18, Loss: 1348.7959
# Test Mean Squared Error: 13.2037
# Epoch 19, Loss: 1344.8320
# Test Mean Squared Error: 13.2043
# Epoch 20, Loss: 1345.8812
# Test Mean Squared Error: 13.2038
# Epoch 21, Loss: 1347.6952
# Test Mean Squared Error: 13.2044
# Epoch 22, Loss: 1349.6006
# Test Mean Squared Error: 13.2080
# Test Mean Squared Error: 13.2040
# Epoch 64, Loss: 1347.9159
# Test Mean Squared Error: 13.2032
# Epoch 65, Loss: 1345.0960
# Test Mean Squared Error: 13.2032
# Epoch 66, Loss: 1345.5804
# Test Mean Squared Error: 13.2033
# Epoch 67, Loss: 1345.2597
# Test Mean Squared Error: 13.2037
# Epoch 68, Loss: 1344.7282
# Test Mean Squared Error: 13.2031
# Epoch 69, Loss: 1348.1865
# Test Mean Squared Error: 13.2032
# Epoch 70, Loss: 1343.3996
# Test Mean Squared Error: 13.2044
# Epoch 71, Loss: 1346.8496
# Test Mean Squared Error: 13.2032
# Epoch 72, Loss: 1347.0297
# Test Mean Squared Error: 13.2033
# Epoch 73, Loss: 1346.2335
# Test Mean Squared Error: 13.2038
# Epoch 74, Loss: 1348.4118
# Test Mean Squared Error: 13.2033
# Epoch 75, Loss: 1348.5343
# Test Mean Squared Error: 13.2041
# Epoch 76, Loss: 1347.1777
# Test Mean Squared Error: 13.2035
# Epoch 77, Loss: 1346.6970
# Test Mean Squared Error: 13.2079
# Epoch 78, Loss: 1345.7088
# Test Mean Squared Error: 13.2057
# Epoch 79, Loss: 1347.1573
# Test Mean Squared Error: 13.2057
# Epoch 80, Loss: 1346.8371
# Test Mean Squared Error: 13.2045
# Epoch 81, Loss: 1344.6507
# Test Mean Squared Error: 13.2031
# Epoch 82, Loss: 1344.7732
# Test Mean Squared Error: 13.2034
# Epoch 83, Loss: 1348.1312
# Test Mean Squared Error: 13.2035
# Epoch 84, Loss: 1347.3722
# Test Mean Squared Error: 13.2050
# Epoch 85, Loss: 1350.8362
# Test Mean Squared Error: 13.2052
# Epoch 86, Loss: 1349.1058
# Test Mean Squared Error: 13.2049
# Epoch 87, Loss: 1347.0345
# Test Mean Squared Error: 13.2045
# Epoch 88, Loss: 1348.9999
# Test Mean Squared Error: 13.2056
# Epoch 89, Loss: 1346.8270
# Test Mean Squared Error: 13.2041
# Epoch 90, Loss: 1345.7262
# Test Mean Squared Error: 13.2049
# Epoch 91, Loss: 1349.4977
# Test Mean Squared Error: 13.2042
# Epoch 92, Loss: 1347.3484
# Test Mean Squared Error: 13.2038
# Epoch 93, Loss: 1347.7951
# Test Mean Squared Error: 13.2039
# Epoch 94, Loss: 1346.1661
# Test Mean Squared Error: 13.2037
# Epoch 95, Loss: 1349.0596
# Test Mean Squared Error: 13.2047
# Epoch 96, Loss: 1350.0884
# Test Mean Squared Error: 13.2045
# Epoch 97, Loss: 1347.1157
# Test Mean Squared Error: 13.2053
# Epoch 98, Loss: 1344.7644
# Test Mean Squared Error: 13.2033
# Epoch 99, Loss: 1348.8318
# Test Mean Squared Error: 13.2032
# Epoch 100, Loss: 1347.2014
# Test Mean Squared Error: 13.2051

# %%
# plot training and test losses
import matplotlib.pyplot as plt
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# get the r2 score of the dnn model on test test
preds = model(torch.tensor(X_test, dtype=torch.float32)).detach().numpy()
from sklearn.metrics import r2_score
r2 = r2_score(y_test, preds)
print(f"R2 score of DNN model on test set: {r2}")
# Out:
# R2 score of DNN model on test set: -0.0001482179301903752
